# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Landslide project/actual location data 7 november 2025.csv")
#df = pd.read_csv("/content/Landslide.csv")

# %%
df
# Out:
#       timestamp  devID       soil  rain       temp       humi        geo  \
# 0       45:12.2    108   1.604698   0.0  34.700001  59.799999  -1.000000
# 1       45:32.2    108   1.604698   0.0  34.900002  64.000000  -1.000000
# 2       45:52.2    108   1.604698   0.0  34.833335  62.600000   1.000000
# 3       46:12.2    108   1.604698   0.0  34.900002  64.000000  -1.000000
# 4       46:32.3    108   1.604698   0.0  34.900002  62.200001  -1.000000
# ...         ...    ...        ...   ...        ...        ...        ...
# 24327   58:48.2    109  36.599998   0.0  31.200001  67.599998  15.310984
# 24328   58:49.9    108  46.500000   0.0  28.900000  82.500000   7.489332
# 24329   59:11.2    106  40.200001   0.0  30.200001  74.099998   0.506784
# 24330   59:33.3    109  36.500000   0.0  31.250000  69.099998   9.234043
# 24331   59:34.9    108  46.500000   0.0  28.900000  81.500000   8.748539
#
#             lat        lng  iso_score  iso_risk  lstm_score  lstm_risk  \
# ...

# %%
df1 = df[['timestamp','devID','soil', 'rain', 'temp', 'humi', 'geo']]
display(df1.head())
# Out:
#   timestamp  devID      soil  rain       temp       humi  geo
# 0   45:12.2    108  1.604698   0.0  34.700001  59.799999 -1.0
# 1   45:32.2    108  1.604698   0.0  34.900002  64.000000 -1.0
# 2   45:52.2    108  1.604698   0.0  34.833335  62.600000  1.0
# 3   46:12.2    108  1.604698   0.0  34.900002  64.000000 -1.0
# 4   46:32.3    108  1.604698   0.0  34.900002  62.200001 -1.0

# %%
df1
# Out:
#       timestamp  devID       soil  rain       temp       humi        geo
# 0       45:12.2    108   1.604698   0.0  34.700001  59.799999  -1.000000
# 1       45:32.2    108   1.604698   0.0  34.900002  64.000000  -1.000000
# 2       45:52.2    108   1.604698   0.0  34.833335  62.600000   1.000000
# 3       46:12.2    108   1.604698   0.0  34.900002  64.000000  -1.000000
# 4       46:32.3    108   1.604698   0.0  34.900002  62.200001  -1.000000
# ...         ...    ...        ...   ...        ...        ...        ...
# 24327   58:48.2    109  36.599998   0.0  31.200001  67.599998  15.310984
# 24328   58:49.9    108  46.500000   0.0  28.900000  82.500000   7.489332
# 24329   59:11.2    106  40.200001   0.0  30.200001  74.099998   0.506784
# 24330   59:33.3    109  36.500000   0.0  31.250000  69.099998   9.234043
# 24331   59:34.9    108  46.500000   0.0  28.900000  81.500000   8.748539
#
# [24332 rows x 7 columns]

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
df1 = df1.sort_values(by='timestamp')

# Filter
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='soil', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Soil Moisture Over Time ')
plt.xlabel('Timestamp')
plt.ylabel('Soil Moisture')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-205398874.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
# /tmp/ipython-input-205398874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
# /tmp/ipython-input-205398874.py:9: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='soil', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
df1 = df1.sort_values(by='timestamp')

# Filter
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='rain', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Rainfall over Time ')
plt.xlabel('Timestamp')
plt.ylabel('Rain')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-649652055.py:9: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='rain', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
df1 = df1.sort_values(by='timestamp')

# Filter
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='humi', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Humidity Over Time ')
plt.xlabel('Timestamp')
plt.ylabel('Humidity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-821778085.py:9: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='humi', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
df1 = df1.sort_values(by='timestamp')

# Filter
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='temp', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Temperature Over Time ')
plt.xlabel('Timestamp')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3712637562.py:9: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='temp', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
df1['timestamp'] = pd.to_datetime(df1['timestamp'], errors='coerce')
df1 = df1.sort_values(by='timestamp')

# Filter
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='geo', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Geophone Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Geophone')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-691141329.py:9: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='geo', hue='devID',palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
# Exclude devID 105 and 104
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='soil', hue='devID')
plt.title('Soil Moisture over Time by Device ID (Excluding devID 105 and 104)')
plt.xlabel('Timestamp')
plt.ylabel('Soil Moisture')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Exclude devID 105 and 104
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='rain', hue='devID')
plt.title('Rainfall over Time by Device ID (Excluding devID 105 and 104)')
plt.xlabel('Timestamp')
plt.ylabel('Rainfall')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Exclude devID 105
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='humi', hue='devID', palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Humidity over Time by Device ID (Excluding devID 105)')
plt.xlabel('Timestamp')
plt.ylabel('Humidity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2142386095.py:6: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='humi', hue='devID', palette=['red', 'green', 'blue', 'black', 'orange'])

# %%
# Exclude devID 105
df1_filtered = df1[df1['devID'] != 105]
df1_filtered = df1_filtered[df1_filtered['devID'] != 104]

plt.figure(figsize=(12, 6))
sns.lineplot(data=df1_filtered, x='timestamp', y='temp', hue='devID', palette=['red', 'green', 'blue', 'black', 'orange'])
plt.title('Temperature over Time by Device ID (Excluding devID 105)')
plt.xlabel('Timestamp')
plt.ylabel('Temperature')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2774002787.py:6: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.lineplot(data=df1_filtered, x='timestamp', y='temp', hue='devID', palette=['red', 'green', 'blue', 'black', 'orange'])

# %% [markdown]
# # Task
# Generate a time series line plot of each feature ('soil', 'rain', 'temp', 'humi', 'geo') separately and together for `devID` 108 from the file "/content/soil moisture.png".

# %% [markdown]
# ## Filter data for devid 108
#
# ### Subtask:
# Create a new DataFrame containing only the data for `devID` 108.

# %% [markdown]
# **Reasoning**:
# Create a new DataFrame by filtering `df1` to include only rows where `devID` is 108.

# %%
df_108 = df1[df1['devID'] == 108].copy()
display(df_108.head())
# Out:
#                 timestamp  devID       soil  rain       temp       humi  \
# 2324  2025-11-27 00:01:12    108  41.766666   0.0  32.499999  72.566666
# 20339 2025-11-27 00:01:24    108  42.099998   0.0  30.600000  80.599998
# 13963 2025-11-27 00:01:48    108  41.099998   0.0  21.900000  95.549999
# 16212 2025-11-27 00:02:24    108  41.000000   0.0  28.100000  85.250000
# 1387  2025-11-27 00:02:30    108  41.700001   0.0  23.700001  96.500000
#
#              geo
# 2324    4.669465
# 20339  14.780882
# 13963  12.542051
# 16212   4.762687
# 1387    7.150796

# %% [markdown]
# ## Plot each feature separately
#
# ### Subtask:
# Generate a separate time series line plot for each feature ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data.

# %% [markdown]
# **Reasoning**:
# Iterate through the features and generate a separate line plot for each using the filtered data for devID 108.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']

for feature in features:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_108, x='timestamp', y=feature)
    plt.title(f'{feature.capitalize()} over Time for devID 108')
    plt.xlabel('Timestamp')
    plt.ylabel(feature.capitalize())
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Plot all features together
#
# ### Subtask:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data on the same plot.

# %% [markdown]
# **Reasoning**:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']
colors = ['blue', 'green', 'red', 'black', 'orange']

plt.figure(figsize=(12, 6))

for i, feature in enumerate(features):
    sns.lineplot(data=df_108_filtered_geo, x='timestamp', y=feature, label=feature.capitalize(), color=colors[i])

plt.title('All sensors over Time for devID 108')
plt.xlabel('Timestamp')
plt.ylabel('Feature Value')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-471716645.py in <cell line: 0>()
#       5
#       6 for i, feature in enumerate(features):
# ----> 7     sns.lineplot(data=df_108_filtered_geo, x='timestamp', y=feature, label=feature.capitalize(), color=colors[i])
#       8
#       9 plt.title('All sensors over Time for devID 108')
#
# NameError: name 'df_108_filtered_geo' is not defined

# %%
df_filtered_geo = df1[(df1['geo'] >= 0) & (df1['geo'] <= 35)].copy()
df_108_filtered_geo = df_filtered_geo[df_filtered_geo['devID'] == 108].copy()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Separate time series plots were generated for each feature ('soil', 'rain', 'temp', 'humi', 'geo') for `devID` 108, showing the trend of each feature over time.
# *   A single time series plot was generated, combining all features ('soil', 'rain', 'temp', 'humi', 'geo') on the same axes for `devID` 108, allowing for visual comparison of their trends over time.
#
# ### Insights or Next Steps
#
# *   Analyze the generated plots to identify potential correlations or patterns between the different features for `devID` 108.
# *   Consider applying time series analysis techniques to further investigate the trends and relationships observed in the data for `devID` 108.

# %% [markdown]
# # Task
# Filter the dataframe `df1` to select data for `devID` 109, then filter this data to exclude 'geo' readings below 0 and above 35. Finally, create separate time series line plots for each feature ('soil', 'rain', 'temp', 'humi', 'geo') and a combined time series line plot for all features for the filtered data.

# %% [markdown]
# ## Filter data for devid 109
#
# ### Subtask:
# Create a new DataFrame containing only the data for `devID` 109.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame `df1` to include only rows where `devID` is 109 and display the head of the resulting DataFrame.

# %%
df_109 = df1[df1['devID'] == 109].copy()
display(df_109.head())

# %% [markdown]
# ## Filter geo readings for devid 109
#
# ### Subtask:
# Filter the DataFrame for `devID` 109 to exclude 'geo' readings below 0 and above 35.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame for devID 109 to exclude 'geo' readings below 0 and above 35.

# %%
df_109_filtered_geo = df_109[(df_109['geo'] >= 0) & (df_109['geo'] <= 35)].copy()
display(df_109_filtered_geo.head())

# %% [markdown]
# ## Plot each feature separately for devid 109
#
# ### Subtask:
# Generate a separate time series line plot for each feature ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data for `devID` 109.

# %% [markdown]
# **Reasoning**:
# Iterate through the features and generate a separate line plot for each using the filtered data for devID 109.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']

for feature in features:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_109_filtered_geo, x='timestamp', y=feature)
    plt.title(f'{feature.capitalize()} over Time for devID 109')
    plt.xlabel('Timestamp')
    plt.ylabel(feature.capitalize())
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Plot all features together for devid 109
#
# ### Subtask:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data for `devID` 109 on the same plot.

# %% [markdown]
# **Reasoning**:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']
colors = ['blue', 'green', 'red', 'black', 'orange']

plt.figure(figsize=(12, 6))

for i, feature in enumerate(features):
    sns.lineplot(data=df_109_filtered_geo, x='timestamp', y=feature, label=feature.capitalize(), color=colors[i])

plt.title('All Sensors over Time for devID 109 ')
plt.xlabel('Timestamp')
plt.ylabel('Feature Value')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The data was successfully filtered to include only records for `devID` 109.
# *   Further filtering was applied to the `devID` 109 data to exclude 'geo' readings below 0 and above 35.
# *   Separate time series line plots were generated for each of the features: 'soil', 'rain', 'temp', 'humi', and 'geo', showing their trends over time for the filtered data.
# *   A combined time series line plot was created, displaying all five features on the same plot, allowing for a visual comparison of their trends over time for `devID` 109 with filtered 'geo' readings.
#
# ### Insights or Next Steps
#
# *   Analyzing the individual and combined time series plots can reveal relationships or correlations between the different features for `devID` 109 within the specified 'geo' range.
# *   Further investigation could involve analyzing data for other `devID`s or exploring different filtering criteria for the 'geo' feature to understand variations and patterns across different devices or conditions.

# %% [markdown]
# # Task
# From df1 data, select devID 106, delete geo reading below 0 and above 35, and line plot time series of each feature separately and finally togather.

# %% [markdown]
# ## Filter data for devid 106
#
# ### Subtask:
# Create a new DataFrame containing only the data for `devID` 106.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame `df1` to include only rows where `devID` is 106 and display the head of the resulting DataFrame.

# %%
df_106 = df1[df1['devID'] == 106].copy()
display(df_106.head())

# %% [markdown]
# ## Filter geo readings for devid 106
#
# ### Subtask:
# Filter the DataFrame for `devID` 106 to exclude 'geo' readings below 0 and above 35.

# %% [markdown]
# **Reasoning**:
# Filter the DataFrame for devID 106 to exclude 'geo' readings below 0 and above 35.

# %%
df_106_filtered_geo = df_106[(df_106['geo'] >= 0) & (df_106['geo'] <= 35)].copy()
display(df_106_filtered_geo.head())

# %% [markdown]
# ## Plot each feature separately for devid 106
#
# ### Subtask:
# Generate a separate time series line plot for each feature ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data for `devID` 106.

# %% [markdown]
# **Reasoning**:
# Iterate through the features and generate a separate line plot for each using the filtered data for devID 106.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']

for feature in features:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df_106_filtered_geo, x='timestamp', y=feature)
    plt.title(f'{feature.capitalize()} over Time for devID 106')
    plt.xlabel('Timestamp')
    plt.ylabel(feature.capitalize())
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Reasoning**:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data for devID 106.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']
colors = ['blue', 'green', 'red', 'black', 'orange']

plt.figure(figsize=(12, 6))

for i, feature in enumerate(features):
    sns.lineplot(data=df_106_filtered_geo, x='timestamp', y=feature, label=feature.capitalize(), color=colors[i])

plt.title('All Sensors over Time for devID 106 ')
plt.xlabel('Timestamp')
plt.ylabel('Feature Value')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df2 = df1[(df1['geo'] >= 0) & (df1['geo'] <= 35)].copy()
df2['geo'] = df2['geo'] / 2
display(df2.head())

# %% [markdown]
# ## Plot all features together for devid 106
#
# ### Subtask:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data for `devID` 106 on the same plot.

# %% [markdown]
# **Reasoning**:
# Generate a single time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for the filtered data.

# %%
features = ['soil', 'rain', 'temp', 'humi', 'geo']
colors = ['blue', 'green', 'red', 'black', 'orange']

plt.figure(figsize=(12, 6))

for i, feature in enumerate(features):
    sns.lineplot(data=df2, x='timestamp', y=feature, label=feature.capitalize(), color=colors[i])

plt.title('All Features over Time (from df2)')
plt.xlabel('Timestamp')
plt.ylabel('Feature Value')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The data for `devID` 106 was successfully isolated from the original dataset.
# *   Rows with 'geo' readings outside the range of 0 to 35 (inclusive) were removed for `devID` 106.
# *   Time series line plots were generated separately for each feature ('soil', 'rain', 'temp', 'humi', 'geo') for `devID` 106.
# *   A combined time series line plot showing all features ('soil', 'rain', 'temp', 'humi', 'geo') for `devID` 106 was successfully generated.
#
# ### Insights or Next Steps
#
# *   The visualizations allow for observing the individual and collective trends of different environmental features over time for `devID` 106, potentially revealing correlations or patterns.
# *   Further analysis could involve investigating specific time periods where interesting fluctuations or relationships between features are observed in the plots.
